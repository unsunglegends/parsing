# %%
from urllib.request import urlopen
url = "https://onesoil.ai/en/"
page = urlopen(url)
page

# %%
html_bytes = page.read()

# %%
html = html_bytes.decode("utf-8")

# %%
print(html)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <meta charset="utf-8">
#     <title>OneSoil | Free precision farming apps</title>
#     <meta name="viewport" content="width=device-width, initial-scale=1, user-scalable=0">
#     <meta name="description" content="Monitor your fields remotely and make reliable agricultural decisions with help from artificial intelligence. For free.">
#     <meta name="Keywords" content="precision agriculture, agricultural decisions">
#     <meta name="author" content="">
#     <meta name="facebook-domain-verification" content="d82zmq8d20dz9uvxdzg16bdnxfkml8">
#     <link rel="stylesheet" href="/css/main.css?ver=1.0.7">
#     <link rel="icon" type="image/png" href="/img/favicons/fav-site-16x16.png" sizes="16x16">
#     <link rel="icon" type="image/png" href="/img/favicons/fav-site-32x32.png" sizes="32x32">
#     <meta property="og:url" content="">
#     <meta property="og:type" content="">
#     <meta property="og:title" content="">
# ...

# %%
import re

match_results = re.findall(r'\bf[a-z]*', html, re.IGNORECASE)


match_results
# Out:
# ['Free',
#  'farming',
#  'fields',
#  'from',
#  'For',
#  'free',
#  'facebook',
#  'favicons',
#  'fav',
#  'favicons',
#  'fav',
#  'function',
#  'f',
#  'f',
#  'f',
#  'fields',
#  'fields',
#  'fill',
#  'fill',
#  'fill',
#  'fill',
#  'For',
#  'For',
#  'fill',
#  'fill',
#  'fill',
#  'fff',
#  'fill',
#  'fill',
#  'fill',
#  'fill',
#  'For',
#  'For',
#  'fullwidth',
#  'for',
#  'footer',
#  'footer',
#  'footer',
#  'float',
#  'float',
#  'float',
#  'float',
#  'fade',
#  'Free',
#  'for',
#  'farming',
#  'fade',
#  'find',
#  'fields',
#  'fertilizer',
#  'for',
#  'free',
#  'form',
#  'fullheight',
#  'form',
#  'float',
#  'float',
#  'float',
#  'float',
#  'fact',
#  'fact',
#  'fact',
#  'fact',
#  'fact',
#  'fields',
#  'fact',
#  'field',
#  'fact',
#  'fact',
#  'fact',
#  'fact',
#  'fact',
#  'fast',
#  'fact',
#  'field',
#  'fact',
#  'fact',
#  'fact',
#  'fact',
#  'fact',
#  'fact',
#  'freedom',
#  'from',
#  'fields',
#  'from',
#  'forecast',
# ...

# %%
import nltk


from nltk.corpus import stopwords
print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(html, "html.parser")
soup.getText()
# Out:
# "\n\n\n\nOneSoil | Free precision farming apps\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nWe’ve released an\xa0interactive map with AI-detected fields and\xa0crops.\xa0Interactive map with fields and\xa0crops.\xa0Explore it\xa0here\n\n\n\n\n\n\n\n\n\n\n\n\n\nThe AppsDevicesTechnologyFor BusinessesTeamSupportBlog\n\nSign in\n\n\n\n\n\n\n\n\n\nAboutThe AppsDevicesTechnologyFor BusinessesTeamSupportBlog\n\n\nOpen in\xa0the browserSign in\n\nOneSoil for mobile devices\n\n\n\nDownload\n\n\n\nDownload\n\n\n\nDownload\n\n\n\n\n\n\n\n\n\n\n\n\nFree apps for\xa0precision\xa0farming\nMonitor your crops remotely, find problem spots in\xa0your fields, add notes, apply variable fertilizer rates, create seeding prescriptions, and monitor crop rotation. All for free with OneSoil.\n\n\n\n\nSign up\n\nAlready have an\xa0account? Sign in\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nAdd fields easily\nWe’ve delineated field borders in\xa057\xa0countries worldwide\n\n\n\n\n\n\n\nGet data processed fast\nSee you
# ...

# %%
from nltk.tokenize import word_tokenize
nltk.download('punkt')
stop_words = set(stopwords.words('english'))
 
word_tokens = word_tokenize(soup.getText())
 
filtered_sentence = [w for w in word_tokens if not w.lower() in stop_words]
 
filtered_sentence = []
 
for w in word_tokens:
    if w not in stop_words:
        filtered_sentence.append(w)
 
print(word_tokens)
print(filtered_sentence)
# Out:
# [nltk_data] Downloading package punkt to /home/chaitanya/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ...

# %%
from nltk import word_tokenize, pos_tag, ne_chunk
from nltk import RegexpParser
from nltk import Tree
import pandas as pd

def get_continuous_chunks(text, chunk_func=ne_chunk):
    chunked = chunk_func(pos_tag(word_tokenize(text)))
    continuous_chunk = []
    current_chunk = []

    for subtree in chunked:
        if type(subtree) == Tree:
            current_chunk.append(" ".join([token for token, pos in subtree.leaves()]))
        elif current_chunk:
            named_entity = " ".join(current_chunk)
            if named_entity not in continuous_chunk:
                continuous_chunk.append(named_entity)
                current_chunk = []
        else:
            continue

    return continuous_chunk

df = pd.DataFrame({'text':[soup.getText()]})

df['text'].apply(lambda sent: get_continuous_chunks((sent)))
# Out:
# 0    [OneSoil, AppsDevicesTechnologyFor, AboutThe, ...
# Name: text, dtype: object

# %%
set1 = df['text'].apply(lambda sent: get_continuous_chunks((sent)))

# %%
for i in set1:
    print(i)
# Out:
# OneSoil
